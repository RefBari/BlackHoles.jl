# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import autograd.numpy as anp
from autograd import grad

# %% [markdown]
# # Create Schwarzschild Metric

# %% [markdown]
# # Define Poisson Matrix

# %% [markdown]
# # Define $\nabla E$

# %% [markdown]
# # Equations of Motion

# %% [markdown]
# # Parameters

# %% [markdown]
# # Initial Conditions

# %%
def Angular_Momentum(r, M):
  return np.sqrt((M*r)/(1-(3*M)/r))

def Elliptical_Orbit_Energy(r, M, p_r, p_phi):
  H0 = -0.5
  f = 1 - (2*M/r)
  E2 = -(f) * (2*H0 - (p_phi**2)/(r**2) - f*(p_r**2))
  return np.sqrt(E2)

L = Angular_Momentum(R, M)
E = Elliptical_Orbit_Energy(R, M, BH_Kick, L)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-920654534.py in <cell line: 0>()
#       8   return np.sqrt(E2)
#       9
# ---> 10 L = Angular_Momentum(R, M)
#      11 E = Elliptical_Orbit_Energy(R, M, BH_Kick, L)
#
# NameError: name 'R' is not defined

# %% [markdown]
# # Integrate Equations to get Geodesic

# %% [markdown]
# # Plot Schwarzschild Geodesics!
